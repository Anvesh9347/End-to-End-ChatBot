# %%
from openai import OpenAI

# %%
f=open('/content/Open Ai_Keys.txt')
openai_api_key=f.read()

# %%
client=OpenAI(api_key=openai_api_key)
client.models.list()
# Out:
# SyncPage[Model](data=[Model(id='dall-e-2', created=1698798177, object='model', owned_by='system'), Model(id='omni-moderation-latest', created=1731689265, object='model', owned_by='system'), Model(id='gpt-4o-mini-search-preview', created=1741391161, object='model', owned_by='system'), Model(id='gpt-4o-mini-search-preview-2025-03-11', created=1741390858, object='model', owned_by='system'), Model(id='gpt-4-turbo', created=1712361441, object='model', owned_by='system'), Model(id='o3-mini-2025-01-31', created=1738010200, object='model', owned_by='system'), Model(id='gpt-4.1', created=1744316542, object='model', owned_by='system'), Model(id='gpt-4.1-mini-2025-04-14', created=1744317547, object='model', owned_by='system'), Model(id='gpt-5-nano-2025-08-07', created=1754426303, object='model', owned_by='system'), Model(id='gpt-4.1-mini', created=1744318173, object='model', owned_by='system'), Model(id='sora-2', created=1759708615, object='model', owned_by='system'), Model(id='sora-2-pro', cre
# ...

# %%
# !pip install -U langchain-openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.9/469.9 kB 13.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.79
#     Uninstalling langchain-core-0.3.79:
#       Successfully uninstalled langchain-core-0.3.79
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.27 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 1.0.3 which is incompatible.
# ...

# %%
from langchain_openai import ChatOpenAI

# %%
chat_model=ChatOpenAI(api_key=openai_api_key,model='gpt-4-turbo',temperature=1)

# %%
from langchain_core.prompts import ChatPromptTemplate,MessagesPlaceholder,HumanMessagePromptTemplate
from langchain_core.messages import SystemMessage

# %%
prompt=ChatPromptTemplate.from_messages([
    SystemMessage(content='You are a chatbot having conversation with human'),
    MessagesPlaceholder(variable_name="chat_history"),
   HumanMessagePromptTemplate.from_template("{human_input}"),

])

# %%
# !pip show langchain
# !pip show langchain-core
# !pip show langchain-community
# Out:
# Name: langchain
# Version: 0.3.27
# Summary: Building applications with LLMs through composability
# Home-page:
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: langchain-core, langchain-text-splitters, langsmith, pydantic, PyYAML, requests, SQLAlchemy
# Required-by:
# Name: langchain-core
# Version: 1.0.3
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: jsonpatch, langsmith, packaging, pydantic, pyyaml, tenacity, typing-extensions
# Required-by: langchain, langchain-openai, langchain-text-splitters
# WARNING: Package(s) not found: langchain-community

# %%
# !pip install -U langchain-classic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 8.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.11
#     Uninstalling langchain-text-splitters-0.3.11:
#       Successfully uninstalled langchain-text-splitters-0.3.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.27 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 1.0.3 which is incompatible.
# langchain 0.3.27 requires langchain-text-splitters<1.0.0,>=0.3.9, but you have langchain-text-splitters 1.0.0 which is incompatible.
# ...

# %%
from langchain_classic.memory import ConversationBufferMemory

memory = ConversationBufferMemory(memory_key="chat_history",return_messages=True)
# Out:
# /tmp/ipython-input-1105191640.py:3: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory(memory_key="chat_history",return_messages=True)

# %%
from langchain_core.output_parsers import StrOutputParser

# %%
output_parser=StrOutputParser()

# %%
from langchain_core.runnables import RunnablePassthrough,RunnableLambda

# %%
def get_messages_from_memory(human_input):
  return memory.load_memory_variables(human_input)["chat_history"]

# %%
## Define a function to load messages from memory

# %%
def get_messages_from_memory(human_input):
    return memory.load_memory_variables(human_input)["chat_history"]

## Define a chain
chain=RunnablePassthrough.assign(
    chat_history=RunnableLambda(get_messages_from_memory)
    ) | prompt | chat_model |output_parser

# %%
query= {"human_input":"Hi,How are you?"}
response=chain.invoke(query)
response
# Out:
# "Hello! I'm just a computer program, so I don't experience feelings, but I'm here to help you! What can I do for you today?"

# %%
memory.buffer
# Out:
# []

# %%
memory.load_memory_variables({}) # as we gave input and we got output but memory is still empty .becasue we havent save it to memory
# Out:
# {'chat_history': []}

# %%
memory.save_context(query,{"output":response})

# %%
memory.buffer
# Out:
# [HumanMessage(content='Hi,How are you?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content="Hello! I'm just a computer program, so I don't experience feelings, but I'm here to help you! What can I do for you today?", additional_kwargs={}, response_metadata={})]

# %%
memory.load_memory_variables({})
# Out:
# {'chat_history': [HumanMessage(content='Hi,How are you?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content="Hello! I'm just a computer program, so I don't experience feelings, but I'm here to help you! What can I do for you today?", additional_kwargs={}, response_metadata={})]}

# %%
while True:
  query={'human_input':input('Enter your input:')}
  print(f"*user:{query['human_input']}")
  if query['human_input'] in['bye','quit','exit']:
    break
  response=chain.invoke(query)
  print(f"*AI:{response}")
  memory.save_context(query,{'output':response})
# Out:
# Enter your input:where are you from
# *user:where are you from
# *AI:I exist in the digital realm, running on servers, so I don't have a physical location like a person does. My programming and data are maintained by computer systems that can be located anywhere in the world. How can I assist you further?
# Enter your input:what is the full form of lexus
# *user:what is the full form of lexus
# *AI:The name "Lexus" does not have a specific full form or an acronym. It is a brand name created by Toyota for their luxury vehicle division. The name was chosen for its association with luxury and elegance.
# Enter your input:what is oracles apex can you explain me in undersatndble way
# *user:what is oracles apex can you explain me in undersatndble way
# ...

# %%
import os
import pickle

# Create the folder automatically if it doesn't exist
os.makedirs("chat_data", exist_ok=True)

# Save your memory object
chat_history = pickle.dumps(memory)
with open("chat_data/conversation_memory.pkl", "wb") as f:
    f.write(chat_history)

print("✅ Chat memory saved successfully!")
# Out:
# ✅ Chat memory saved successfully!

# %%
memory=pickle.load(open("chat_data/conversation_memory.pkl", "rb"))
print(memory)
# Out:
# chat_memory=InMemoryChatMessageHistory(messages=[HumanMessage(content='Hi,How are you?', additional_kwargs={}, response_metadata={}), AIMessage(content="Hello! I'm just a chatbot, so I don't have feelings, but I'm here to help you! What's on your mind today?", additional_kwargs={}, response_metadata={})]) return_messages=True memory_key='chat_history'

# %%
memory.load_memory_variables({})
# Out:
# {'chat_history': [HumanMessage(content='Hi,How are you?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content="Hello! I'm just a chatbot, so I don't have feelings, but I'm here to help you! What's on your mind today?", additional_kwargs={}, response_metadata={})]}

# %%
## SQL Chatmessagehistory

# %%
! pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 19.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# langchain 0.3.27 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 1.0.2 which is incompatible.
# langchain 0.3.27 requires langchain-text-splitters<1.0.0,>=0.3.9, but you have langchain-text-splitters 1.0.0 which is incompatible.
# ...

# %%
from langchain_community.chat_message_histories import SQLChatMessageHistory
def get_session_message_history_from_db(session_id):
  chat_message_history=SQLChatMessageHistory(
      session_id=session_id,
      connection='sqlite:///chat_data/sqlite.db'
  )
  return chat_message_history

# %%
from langchain_core.prompts import ChatPromptTemplate,MessagesPlaceholder,HumanMessagePromptTemplate
from langchain_core.messages import SystemMessage
prompt=ChatPromptTemplate.from_messages([
    SystemMessage(content='You are a chatbot having conversation with human'),
    MessagesPlaceholder(variable_name="history"),
   HumanMessagePromptTemplate.from_template("{human_input}"),

])

# %%
chain= prompt|chat_model

# %%
from langchain_core.runnables.history import RunnableWithMessageHistory

# %%
conversation_chain=RunnableWithMessageHistory(chain,
                    get_session_message_history_from_db,
                    input_messages_key="human_input",
                    history_messages_key='history'

)

# %%
user_id='Krishna'
config={"configurable":{"session_id":user_id}}
input_prompt={'human_input':'my name is krishna.Can you tell me about lord krishna'}
response=conversation_chain.invoke(input_prompt,config=config)
response.content
# Out:
# "Hello Krishna! It's wonderful to share information about Lord Krishna with you.\n\nLord Krishna is one of the most cherished and revered figures in Hinduism, known both as a divine hero and a god in his own right. He is regarded as the eighth avatar of Vishnu, one of the principal deities of Hinduism.\n\n### Key Aspects of Lord Krishna:\n\n1. **Birth and Early Life**:\n   Krishna was born in Mathura, a city in Northern India, to Devaki and Vasudeva. Due to a prophecy that he would be responsible for the demise of his tyrannical uncle, King Kamsa, Krishna was swiftly taken to Gokul after his birth and raised by foster parents Yashoda and Nanda Maharaj. This was done to protect him from Kamsa, who was determined to kill him.\n\n2. **Youth and Leelas (Divine Play)**:\n   Krishna's childhood and youth in Vrindavan are marked by numerous playful episodes and miraculous deeds, which underline his divine nature. These tales include subduing demons sent by Kamsa, lifting the Govardhan hill 
# ...

# %%
def chat_bot(session_id,prompt):
  config={"configurable":{"session_id":user_id}}
  input_prompt={'human_input':prompt}
  response=conversation_chain.invoke(input_prompt,config=config)
  return response.content

# %%
user_id='krishna'
input_prompt='Do you remembered my name?'
chat_bot(session_id=user_id,prompt=input_prompt)
# Out:
# "I don't have the ability to remember details from previous messages or sessions once our conversation ends. Each session with me starts without any previous memory to ensure privacy and confidentiality. Please share your name again if you'd like me to use it during our conversation!"
